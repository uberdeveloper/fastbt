# %% [markdown]
# ## Introduction
# DataSource is a helper class for doing montonous, repetitive tasks related to financial time series data. Quite often, we need to apply a set of common functions such as shifting data, calculating rolling statistics, percent changes etc., for each security in our database by using pandas **groupby** function. DataSource simplifies this process by one-liners instead of multiple lines of pandas code; In fact, its just a fancy wrapper for pandas groupby with some extra goodies.
#
# So instead of
# ```python
# shift = lambda x: x.shift(1)
# dataframe['lag_one'] = dataframe.groupby('symbol')['close'].transform(shift)
# ```
# it would be
# ```python
# dataframe.add_lag(on='close', period=1, col_name='lag_one')
# ```
#
# The only requirement is that the dataframe must have **symbol and timestamp columns**.
#
# **If you have them as indexes, reset them as columns**

# %%
import pandas as pd
from fastbt.datasource import DataSource

# %% [markdown]
# ## Initialize DataSource class with a dataframe

# %%
df = pd.read_csv('data/bank.csv', parse_dates=['timestamp'])
ds = DataSource(df)

## Use ds.data to get the dataframe back
ds.data.head()
# Out:
#    timestamp      symbol series     open     high     low   close     last  \
# 0 2018-09-03    AXISBANK     EQ   655.45   655.45   629.6   631.8   630.70
# 1 2018-09-03     RBLBANK     EQ   630.10   643.50   622.0   623.9   624.40
# 2 2018-09-03  INDUSINDBK     EQ  1906.00  1918.85  1884.7  1897.0  1895.00
# 3 2018-09-03   KOTAKBANK     EQ  1292.00  1295.00  1265.0  1269.1  1266.25
# 4 2018-09-03  BANKBARODA     EQ   153.95   156.50   150.9   151.7   151.30
#
#    prevclose  tottrdqty     tottrdval  totaltrades          isin
# 0     649.25    6494484  4.148248e+09        88364  INE238A01034
# 1     627.25    1532438  9.708929e+08        28755  INE976G01028
# 2    1906.60     937981  1.782402e+09        85683  INE095A01012
# 3    1287.25    2076747  2.639495e+09        59594  INE237A01028
# 4     152.95   16081701  2.484263e+09        72339  INE028A01039

# %%
# If your dataframe has a different name for the symbol and timestamp
# column, pass them as parameters during initialization
ds = DataSource(df, symbol='symbol', timestamp='timestamp')

# %% [markdown]
# DataSource adds a column for each function you specify and returns a dataframe with the column added. The existing functions are
#
# ```
#  add_lag
#  add_pct_change
#  add_rolling
#  add_formula
#  add_indicator
# ```
#
# All functions have a col_name argument. Except for ``add_formula``, column names are generated automatically for all functions.
#
# **All column names, even those specified as arguments, are converted into lower case to make them case-insensitive.**
#
# The following arguments are common to the functions
#  * ``col_name`` - column name to be added in dataframe. Mandatory for ``add_formula``, for others added automatically
#  * ``period`` - time period for the function
#  * ``lag`` - time lag; time by which the result is to be lagged. Not applicable for ``add_lag`` and ``add_formula``
#  * ``on`` - column on which the grouping is to be made. Not applicable to ``add_formula`` and ``add_indicator``
#
#  Let's see a few examples

# %% [markdown]
# ## ``add_lag``
#
# adds the given time lag to the specified period

# %%
## Add a one day lag to data
ds.add_lag();
print(ds.data.info()) # Column lag_close_1 added automatically
ds.data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 14 columns):
# timestamp      48 non-null datetime64[ns]
# symbol         48 non-null object
# series         48 non-null object
# open           48 non-null float64
# high           48 non-null float64
# low            48 non-null float64
# close          48 non-null float64
# last           48 non-null float64
# prevclose      48 non-null float64
# tottrdqty      48 non-null int64
# tottrdval      48 non-null float64
# totaltrades    48 non-null int64
# isin           48 non-null object
# lag_close_1    36 non-null float64
# dtypes: datetime64[ns](1), float64(8), int64(2), object(3)
# memory usage: 5.3+ KB
# None
#    timestamp      symbol series     open     high     low   close     last  \
# 0 2018-09-03    AXISBANK     EQ   655.45   655.45   629.6   631.8   630.70
# 1 2018-09-03     RBLBANK     EQ   630.10   643.50   622.0   623.9   624.40
# 2 2018-09-03  INDUSINDBK     EQ  1906.00  1918.85  1884.7  1897.0  1895.00
# 3 2018-09-03   KOTAKBANK     EQ  1292.00  1295.00  1265.0  1269.1  1266.25
# 4 2018-09-03  BANKBARODA     EQ   153.95   156.50   150.9   151.7   151.30
#
#    prevclose  tottrdqty     tottrdval  totaltrades          isin  lag_close_1
# 0     649.25    6494484  4.148248e+09        88364  INE238A01034          NaN
# 1     627.25    1532438  9.708929e+08        28755  INE976G01028          NaN
# 2    1906.60     937981  1.782402e+09        85683  INE095A01012          NaN
# 3    1287.25    2076747  2.639495e+09        59594  INE237A01028          NaN
# 4     152.95   16081701  2.484263e+09        72339  INE028A01039          NaN

# %%
# Add a 2 day lag
ds.add_lag(period=2)

# Add a 3 day lag with a custom column name on the open price
ds.add_lag(period=3, col_name='three_day_lag', on='open').dropna().head()
# Out:
#     timestamp      symbol series     open     high      low    close     last  \
# 36 2018-09-06  FEDERALBNK     EQ    78.50    78.50    76.70    77.35    77.30
# 37 2018-09-06    HDFCBANK     EQ  2049.00  2059.00  2032.60  2052.20  2050.15
# 38 2018-09-06   ICICIBANK     EQ   330.00   331.25   325.50   328.65   327.95
# 39 2018-09-06    IDFCBANK     EQ    45.15    45.40    44.45    44.90    44.70
# 40 2018-09-06    AXISBANK     EQ   638.90   643.30   624.60   638.20   637.50
#
#     prevclose  tottrdqty     tottrdval  totaltrades          isin  \
# 36      77.75    6731974  5.218088e+08        30898  INE171A01029
# 37    2045.85    2600603  5.316363e+09       125530  INE040A01026
# 38     329.65   11322771  3.724325e+09        81857  INE090A01021
# 39      44.85   12803268  5.735607e+08        23485  INE092T01019
# 40     637.65   10026621  6.344121e+09       122891  INE238A01034
#
#     lag_close_1  lag_close_2  three_day_lag  chg_close_2  rol_mean_close_3
# 36        77.75        77.00          81.50    -0.037152         77.366667
# 37      2045.85      2051.80        2069.40    -0.014072       2049.950000
# 38       329.65       328.50         343.60    -0.013467        328.933333
# 39        44.85        44.95          47.95    -0.063674         44.900000
# 40       637.65       641.80         655.45     0.009259        639.216667

# %% [markdown]
# You could use
# ```python
# ds.data.info()
# ```
# to see the added columns at the end of each cell

# %% [markdown]
# ## ``add_pct_change``
# add a percentage change column

# %%
## Add a 2 day percentage change on close price
ds.add_pct_change(on='close', period=2)
# 25     296.40   22922686  6.766403e+09       148306  INE062A01020
# 26     608.00    1533562  9.128527e+08        27460  INE976G01028
# 27    1257.60    2262546  2.806938e+09        74217  INE237A01028
# 28    1855.60     804386  1.481158e+09        45554  INE095A01012
# 29      83.15   21704587  1.794075e+09        54937  INE160A01022
# 30      44.95    9884978  4.405838e+08        19418  INE092T01019
# 31    2051.80    1410377  2.883899e+09        73829  INE040A01026
# 32      77.00   10489491  8.062858e+08        36246  INE171A01029
# 33     145.55   12672028  1.825173e+09        50620  INE028A01039
# 34     641.80    8837398  5.642182e+09       113081  INE238A01034
# 35     328.50   14548867  4.770315e+09       106589  INE090A01021
# 36      77.75    6731974  5.218088e+08        30898  INE171A01029
# 37    2045.85    2600603  5.316363e+09       125530  INE040A01026
# 38     329.65   11322771  3.724325e+09        81857  INE090A01021
# 39      44.85   12803268  5.735607e+08        23485  INE092T01019
# 40     637.65   10026621  6.344121e+09       122891  INE238A01034
# 41     593.55    1766611  1.039492e+09        45182  INE976G01028
# 42     296.55   18001336  5.352603e+09       111206  INE062A01020
# 43    1238.15    2947633  3.706721e+09        66281  INE237A01028
# 44    1854.85    1003340  1.879392e+09        54166  INE095A01012
# 45     144.55   10475666  1.525306e+09        40096  INE028A01039
# 46      83.10   25079939  2.096853e+09        57788  INE160A01022
# 47     343.80   17527530  6.001339e+09       141838  INE528G01027
#
#     lag_close_1  lag_close_2  three_day_lag  chg_close_2
# 0           NaN          NaN            NaN          NaN
# 1           NaN          NaN            NaN          NaN
# 2           NaN          NaN            NaN          NaN
# 3           NaN          NaN            NaN          NaN
# 4           NaN          NaN            NaN          NaN
# 5           NaN          NaN            NaN          NaN
# 6           NaN          NaN            NaN          NaN
# 7           NaN          NaN            NaN          NaN
# 8           NaN          NaN            NaN          NaN
# 9           NaN          NaN            NaN          NaN
# 10          NaN          NaN            NaN          NaN
# 11          NaN          NaN            NaN          NaN
# 12      2075.05          NaN            NaN          NaN
# 13       631.80          NaN            NaN          NaN
# 14       151.70          NaN            NaN          NaN
# 15       623.90          NaN            NaN          NaN
# 16       339.05          NaN            NaN          NaN
# 17        80.75          NaN            NaN          NaN
# 18        86.35          NaN            NaN          NaN
# 19      1269.10          NaN            NaN          NaN
# 20      1897.00          NaN            NaN          NaN
# 21        47.90          NaN            NaN          NaN
# 22       334.15          NaN            NaN          NaN
# 23       306.35          NaN            NaN          NaN
# 24       334.05       339.05            NaN     0.014010
# 25       296.40       306.35            NaN    -0.031990
# 26       608.00       623.90            NaN    -0.048646
# 27      1257.60      1269.10            NaN    -0.024387
# 28      1855.60      1897.00            NaN    -0.022219
# 29        83.15        86.35            NaN    -0.037638
# 30        44.95        47.90            NaN    -0.063674
# 31      2051.80      2075.05            NaN    -0.014072
# 32        77.00        80.75            NaN    -0.037152
# 33       145.55       151.70            NaN    -0.047132
# 34       641.80       631.80            NaN     0.009259
# 35       328.50       334.15            NaN    -0.013467
# 36        77.75        77.00          81.50     0.004545
# 37      2045.85      2051.80        2069.40     0.000195
# 38       329.65       328.50         343.60     0.000457
# 39        44.85        44.95          47.95    -0.001112
# 40       637.65       641.80         655.45    -0.005609
# 41       593.55       608.00         630.10    -0.027056
# 42       296.55       296.40         312.50     0.000169
# 43      1238.15      1257.60        1292.00     0.002624
# 44      1854.85      1855.60        1906.00     0.013149
# 45       144.55       145.55         153.95     0.003779
# 46        83.10        83.15          88.30     0.001203
# 47       343.80       334.05         347.95     0.015417

# %% [markdown]
# Calculate the 2 day percentage change in close price and lag it by one day.
# This is especially useful if you want to know the 2 day returns on the morning of the 3rd day

# %%
ds.add_pct_change(on='close', period=2, lag=1)
ds.data.head()
# Out:
#    timestamp      symbol series     open     high     low   close     last  \
# 0 2018-09-03    AXISBANK     EQ   655.45   655.45   629.6   631.8   630.70
# 1 2018-09-03     RBLBANK     EQ   630.10   643.50   622.0   623.9   624.40
# 2 2018-09-03  INDUSINDBK     EQ  1906.00  1918.85  1884.7  1897.0  1895.00
# 3 2018-09-03   KOTAKBANK     EQ  1292.00  1295.00  1265.0  1269.1  1266.25
# 4 2018-09-03  BANKBARODA     EQ   153.95   156.50   150.9   151.7   151.30
#
#    prevclose  tottrdqty     tottrdval  totaltrades          isin  lag_close_1  \
# 0     649.25    6494484  4.148248e+09        88364  INE238A01034          NaN
# 1     627.25    1532438  9.708929e+08        28755  INE976G01028          NaN
# 2    1906.60     937981  1.782402e+09        85683  INE095A01012          NaN
# 3    1287.25    2076747  2.639495e+09        59594  INE237A01028          NaN
# 4     152.95   16081701  2.484263e+09        72339  INE028A01039          NaN
#
#    lag_close_2  three_day_lag  chg_close_2
# 0          NaN            NaN          NaN
# 1          NaN            NaN          NaN
# 2          NaN            NaN          NaN
# 3          NaN            NaN          NaN
# 4          NaN            NaN          NaN

# %% [markdown]
# You could also pass keyword arguments to the percent change function. These arguments are passed on to the pandas function before computing the results.
# So let's compute the percent change by backfilling NA data

# %%
ds.add_pct_change(on='close', period=2, lag=1, fill_method='bfill');

# %% [markdown]
# ## ``add_rolling``
# add a rolling statistic column

# %%
ds.add_rolling(window=3, on='close', function='mean');
# Out:
# mean

# %% [markdown]
# ## ``add_formula``
# add a formula column
#
# The formula should be a string

# %%
ds.add_formula()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-8a2524e04998> in <module>()
# ----> 1 ds.add_formula()
#
# TypeError: add_formula() missing 2 required positional arguments: 'formula' and 'col_name'

# %% [markdown]
# ## ``add_indicator``
#
# add a technical indicator

# %%
ds.add_indicator('RSI', 2);

# %% [markdown]
# ## A few shortcuts
#
# Adding columns in bulk.

# %%
# Add 2,3,5 day returns
[ds.add_pct_change(on='close', period=i, col_name='ret' + str(i))
 for i in [2,3,5]]
ds.data.info()

# %% [markdown]
# ## ``batch_process``
# Batch process
